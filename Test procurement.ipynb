# %% [markdown]
# test

# %%
import pandas as pd
path= r'H:\Jupyter_test\supplierLeadTime\SLT.csv'

# %%
#encodin utf16
#use the first column as colum names
#parse the following columns as date
test = pd.read_csv(path, encoding='utf16', on_bad_lines='warn', index_col=False, parse_dates=['PO Date','Estimated Delivery Date','Goods Receipt Posting Date','Goods Receipt Document Date'])
# Out:
# c:\users\carlos_castillo\appdata\local\programs\python\python39\lib\site-packages\pandas\core\tools\datetimes.py:1063: UserWarning: Parsing '14.05.2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# c:\users\carlos_castillo\appdata\local\programs\python\python39\lib\site-packages\pandas\core\tools\datetimes.py:1063: UserWarning: Parsing '19.05.2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# c:\users\carlos_castillo\appdata\local\programs\python\python39\lib\site-packages\pandas\core\tools\datetimes.py:1063: UserWarning: Parsing '20.05.2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   cache_array = _maybe_cache(arg, format, cache, convert_listlike)
# ...

# %%
test.head(8)
# Out:
#    #  Document Internal ID    PO Date  Item No.     Q Estimated Delivery Date  \
# 0  1                     1 2014-06-05    200013  20.0              2014-06-05
# 1  2                     1 2014-06-05    200012  20.0              2014-06-05
# 2  3                     1 2014-06-05    200014  10.0              2014-06-05
# 3  4                     2 2014-07-05    500273   8.0              2014-07-05
# 4  5                     3 2014-05-14    500280   1.0              2014-05-22
# 5  6                     4 2014-05-19    700036  50.0              2014-05-19
# 6  7                     5 2014-05-20    700037  50.0              2014-05-30
# 7  8                     6 2014-05-20    500296   1.0              2014-05-20
#
#    BP Code                         BP Name  Goods Receipt Internal ID   Q_r  \
# 0    71908            Turck GmbH  & Co. KG                       78.0  20.0
# 1    71908            Turck GmbH  & Co. KG                       71.0  20.0
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7423 entries, 0 to 7422
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   #                            7423 non-null   int64
#  1   Document Internal ID         7423 non-null   int64
#  2   PO Date                      7423 non-null   datetime64[ns]
#  3   Item No.                     7423 non-null   int64
#  4   Q                            7418 non-null   float64
#  5   Estimated Delivery Date      7423 non-null   datetime64[ns]
#  6   BP Code                      7423 non-null   int64
#  7   BP Name                      7423 non-null   object
#  8   Goods Receipt Internal ID    6971 non-null   float64
#  9   Q_r                          6957 non-null   float64
#  10  Goods Receipt Posting Date   6971 non-null   datetime64[ns]
#  11  Goods Receipt Document Date  6971 non-null   datetime64[ns]
# ...

# %%
#keep all notnull for the goods receipt posting date - only analysis over what have been calculated 
test = test[test['Goods Receipt Posting Date'].notna()]
#keep all null for the Goods_Returned - make sure we have not returned
test = test[test['Goods_Returned'].isna()]

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6870 entries, 0 to 7411
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   #                            6870 non-null   int64
#  1   Document Internal ID         6870 non-null   int64
#  2   PO Date                      6870 non-null   datetime64[ns]
#  3   Item No.                     6870 non-null   int64
#  4   Q                            6867 non-null   float64
#  5   Estimated Delivery Date      6870 non-null   datetime64[ns]
#  6   BP Code                      6870 non-null   int64
#  7   BP Name                      6870 non-null   object
#  8   Goods Receipt Internal ID    6870 non-null   float64
#  9   Q_r                          6857 non-null   float64
#  10  Goods Receipt Posting Date   6870 non-null   datetime64[ns]
#  11  Goods Receipt Document Date  6870 non-null   datetime64[ns]
# ...

# %%
test = test.drop(['#','Document Internal ID','Estimated Delivery Date','Goods Receipt Internal ID','Goods Receipt Posting Date','Goods_Returned','Unnamed: 13'], axis=1)
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6870 entries, 0 to 7411
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   PO Date                      6870 non-null   datetime64[ns]
#  1   Item No.                     6870 non-null   int64
#  2   Q                            6867 non-null   float64
#  3   BP Code                      6870 non-null   int64
#  4   BP Name                      6870 non-null   object
#  5   Q_r                          6857 non-null   float64
#  6   Goods Receipt Document Date  6870 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), int64(2), object(1)
# memory usage: 429.4+ KB

# %%
test.head(10)
# Out:
#       PO Date  Item No.      Q  BP Code                         BP Name  \
# 0  2014-06-05    200013   20.0    71908            Turck GmbH  & Co. KG
# 1  2014-06-05    200012   20.0    71908            Turck GmbH  & Co. KG
# 2  2014-06-05    200014   10.0    71908            Turck GmbH  & Co. KG
# 3  2014-07-05    500273    8.0    71005  Knick Elektronische Messgeräte
# 4  2014-05-14    500280    1.0    70706                         HZ GmbH
# 5  2014-05-19    700036   50.0    71105                          LeitOn
# 9  2014-05-21    400014   50.0    71302                          naujok
# 10 2014-05-21    400017  100.0    71302                          naujok
# 11 2014-05-21    400020   50.0    71302                          naujok
# 12 2014-05-21    400015   50.0    71302                          naujok
#
#       Q_r Goods Receipt Document Date
# 0    20.0                  2014-05-19
# 1    20.0                  2014-05-15
# 2    10.0                  2014-05-15
# ...
