# %% [markdown]
# test

# %%
import pandas as pd
path= r'H:\Jupyter_test\supplierLeadTime\SLT.csv'

# %%
 test = pd.read_csv(path, encoding='utf-16', on_bad_lines='skip')

# %%
test.head()
# Out:
#               #  Document Internal ID                               PO Date  \
# 1 1  06.05.2014                200013                   BI8U-M18-AP6X-H1141
# 2 1  06.05.2014                200012                         RKC4.4T-2/TEL
# 3 1  06.05.2014                200014                           WAK4-10/S90
# 4 2  07.05.2014                500273                              A20210P0
# 5 3  14.05.2014                500280  Antennenring Innendurchmesser 210 mm
#
#      Item No.  Item/Service Description    Quantity  Estimated Delivery Date  \
# 1 1      20.0                         0  06.05.2014                    71908
# 2 1      20.0                         0  06.05.2014                    71908
# 3 1      10.0                         0  06.05.2014                    71908
# 4 2       8.0                         0  07.05.2014                    71005
# 5 3       1.0                         0  22.05.2014                    70706
#
# ...
